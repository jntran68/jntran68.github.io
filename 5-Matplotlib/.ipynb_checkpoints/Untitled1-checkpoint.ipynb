# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# Load the file
gaming_file_to_load = "C:/Users/Nhung Tran/Desktop/JJBCD-Data-Project/Project-For-DataBC/gamingdataset.csv"

# Read the file 
gaming_file_df = pd.read_csv(gaming_file_to_load, encoding="ISO-8859-1")
gaming_file_df
data = gaming_file_df.head() 
data
gaming_file_df['Platform'].nunique()
# Out:
# 31

# %%
# Compare how each platform is doing in each country
# Visisualize revenue per country - Jasmine
# Calculate total sales per country
group_data = gaming_file_df.groupby(['Platform'])[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].sum().reset_index()
#df1.groupby(["City"])[['Name']].count()
#type(group_data)
group_data
# Out:
#    Platform  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0      2600     90.60      5.47      0.00         0.91         97.08
# 1       3DO      0.00      0.00      0.10         0.00          0.10
# 2       3DS     78.87     58.52     97.35        12.63        247.46
# 3        DC      5.43      1.69      8.56         0.27         15.97
# 4        DS    390.71    194.65    175.57        60.53        822.49
# 5        GB    114.32     47.82     85.12         8.20        255.45
# 6       GBA    187.54     75.25     47.33         7.73        318.50
# 7        GC    133.46     38.71     21.58         5.18        199.36
# 8       GEN     19.27      5.52      2.67         0.89         28.36
# 9        GG      0.00      0.00      0.04         0.00          0.04
# 10      N64    139.02     41.06     34.22         4.38        218.88
# 11      NES    125.94     21.15     98.65         5.31        251.07
# 12       NG      0.00      0.00      1.44         0.00          1.44
# ...

# %%
ax = group_data[['NA_Sales', 'EU_Sales','JP_Sales','Other_Sales','Global_Sales']].plot(kind='bar', title ="Total Revenue Per Region", figsize=(15, 10), legend=True, fontsize=12)
ax.set_xlabel(group_data["Platform"], fontsize=12)
ax.set_ylabel("Total Revenue (Dollars)", fontsize=12)
plt.show()

# %%
Platform_list = group_data['Platform'].tolist()
NA_Sales_list = group_data['NA_Sales'].tolist()
EU_Sales_list = group_data['EU_Sales'].tolist()
JP_Sales_list = group_data['JP_Sales'].tolist()
Other_Sales_list = group_data['Other_Sales'].tolist()

# %%
ax = plt.subplot(111)
NA_Sales = ax.bar(index, Platform_list,NA_Sales_list,width=0.5,color='b',align='center')
EU_Sales = ax.bar(index, Platform_list+bar_width,EU_Sales_list,width=0.5,color='g',align='center')
JP_Sales = ax.bar(index, Platform_list, JP_Sales_list,width=0.5,color='r',align='center')
Other_Sales = ax.bar(index, Platform_list, Other_Sales_list,width=0.5,color='y',align='center')
#ax.xaxis_date()
ax.autoscale(tight=True)
ax.legend( (NA_Sales[0], EU_Sales[0], JP_Sales[0], Other_Sales[0]   ), ('x','y','z'))
plt.title("Total Revenue Per Region")
plt.ylabel("Total Revenue (Dollars)")
plt.xlabel("Platform")
plt.grid(True)
plt.legend(loc="best", fontsize="small", fancybox=True)
# Save the Figure
plt.savefig("C:/Users/Nhung Tran/Desktop/JJBCD-Data-Project/Project-For-DataBC/Fig1.png")
# Show the Figure
plt.show()

# %%
n_groups = 31
index = np.arange(n_groups)

ax = plt.subplot(111)
NA_Sales = ax.bar(index, Platform_list,NA_Sales_list,width=0.5,color='b',align='center')
EU_Sales = ax.bar(index, Platform_list,EU_Sales_list,width=0.5,color='g',align='center')
JP_Sales = ax.bar(index, Platform_list, JP_Sales_list,width=0.5,color='r',align='center')
Other_Sales = ax.bar(index, Platform_list, Other_Sales_list,width=0.5,color='y',align='center')
#ax.xaxis_date()
ax.autoscale(tight=True)
ax.legend( (NA_Sales[0], EU_Sales[0], JP_Sales[0], Other_Sales[0]   ), ('x','y','z'))
plt.title("Total Revenue Per Region")
plt.ylabel("Total Revenue (Dollars)")
plt.xlabel("Platform")
plt.grid(True)
plt.legend(loc="best", fontsize="small", fancybox=True)
# Save the Figure
plt.savefig("C:/Users/Nhung Tran/Desktop/JJBCD-Data-Project/Project-For-DataBC/Fig1.png")
# Show the Figure
plt.show()
